# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sp

# %% [markdown]
# # Loading data from Ms Excel

# %%
Stocks = pd.read_csv('C:/Users/shree/Downloads/AI and ML in financial services/mutual funds original.csv')
Stocks.head()
Stocks.reset_index(drop=True, inplace=True)
Stocks=pd.DataFrame(Stocks)
datetime_series = pd.to_datetime(Stocks['Date'])
datetime_index = pd.DatetimeIndex(datetime_series.values)
Stocks=Stocks.set_index(datetime_index)
Stocks.drop('Date',axis=1,inplace=True)
Stocks.index = pd.to_datetime(Stocks.index)
Stocks.head()
# help(pd.read_excel)
# Out:
#             AIBALMA AB Equity  LODFUIA LX Equity  CCASORI MK Equity  \
# 2020-04-17            16.6991             112.35             2.5766
# 2020-04-24            16.8738             112.35             2.5808
# 2020-01-05            16.6996             112.33             2.5811
# 2020-08-05            16.8233             112.33             2.5871
# 2020-05-15            16.9853             112.33             2.5927
#
#             BBFTOP3 KY Equity  CRLCBUU LX Equity  BCUSDLF KK Equity  \
# 2020-04-17            1275.83              10.69              10.76
# 2020-04-24            1276.46              10.69              10.77
# 2020-01-05            1276.78              10.68              10.77
# 2020-08-05            1278.59              10.71              10.77
# 2020-05-15            1279.82              10.68              10.78
#
#             PGPGIFA ID Equity  PFGLAAU LX Equity  ALPCRDA LX Equity  \
# 2020-04-17              1.201             114.32             116.33
# 2020-04-24              1.201             114.32             117.05
# 2020-01-05              1.203             114.97             116.80
# 2020-08-05              1.204             114.97             116.74
# 2020-05-15              1.212             115.36             117.38
#
#             BUTIBLI KY Equity
# 2020-04-17              29.97
# 2020-04-24              29.32
# 2020-01-05              30.00
# 2020-08-05              29.84
# 2020-05-15              29.95

# %% [markdown]
# # Log of percentage change of all stocks in the list

# %%
Ret= Stocks.pct_change().apply(lambda x: np.log(1+x)) # CONVERT TO RETURN
Ret.tail()
# Out:
#             AIBALMA AB Equity  LODFUIA LX Equity  CCASORI MK Equity  \
# 2022-01-14           0.016364                0.0           0.003360
# 2022-01-21          -0.004237                0.0           0.003281
# 2022-01-28           0.000644                0.0          -0.001115
# 2022-04-02           0.005215                0.0          -0.000643
# 2022-11-02          -0.003313                0.0           0.005028
#
#             BBFTOP3 KY Equity  CRLCBUU LX Equity  BCUSDLF KK Equity  \
# 2022-01-14           0.000953          -0.000859                0.0
# 2022-01-21           0.002346           0.000859                0.0
# 2022-01-28           0.000500           0.000859                0.0
# 2022-04-02           0.000063           0.000858                0.0
# 2022-11-02           0.000042          -0.000858                0.0
#
#             PGPGIFA ID Equity  PFGLAAU LX Equity  ALPCRDA LX Equity  \
# 2022-01-14          -0.002225           0.000000          -0.000289
# 2022-01-21           0.000000          -0.007609          -0.001155
# 2022-01-28          -0.000743           0.000000          -0.001229
# 2022-04-02          -0.000743           0.000000          -0.003479
# 2022-11-02          -0.000744           0.000000          -0.000944
#
#             BUTIBLI KY Equity
# 2022-01-14          -0.005821
# 2022-01-21          -0.015088
# 2022-01-28          -0.025576
# 2022-04-02           0.019113
# 2022-11-02          -0.004158

# %% [markdown]
# # Calculating the Mean, standard deviation and other stats

# %%
Ann_Ret = Ret.mean()*52
print(Ann_Ret)
# Out:
# AIBALMA AB Equity    0.164994
# LODFUIA LX Equity    0.020183
# CCASORI MK Equity    0.077905
# BBFTOP3 KY Equity    0.059322
# CRLCBUU LX Equity    0.047072
# BCUSDLF KK Equity    0.007076
# PGPGIFA ID Equity    0.061577
# PFGLAAU LX Equity    0.090445
# ALPCRDA LX Equity    0.091994
# BUTIBLI KY Equity    0.135671
# dtype: float64

# %%
Ann_Risk = Ret.std()*(52)**(0.5)
print(Ann_Risk)
# Out:
# AIBALMA AB Equity    0.052010
# LODFUIA LX Equity    0.006843
# CCASORI MK Equity    0.016388
# BBFTOP3 KY Equity    0.011316
# CRLCBUU LX Equity    0.017065
# BCUSDLF KK Equity    0.002373
# PGPGIFA ID Equity    0.022152
# PFGLAAU LX Equity    0.039963
# ALPCRDA LX Equity    0.027841
# BUTIBLI KY Equity    0.080982
# dtype: float64

# %% [markdown]
# # Calculating the correlation and covariance

# %%
Ret_Covar = Ret.cov()
print(Ret_Covar)
# Out:
#                    AIBALMA AB Equity  LODFUIA LX Equity  CCASORI MK Equity  \
# AIBALMA AB Equity       5.201934e-05       3.937103e-07       4.462164e-06
# LODFUIA LX Equity       3.937103e-07       9.006414e-07      -7.683445e-07
# CCASORI MK Equity       4.462164e-06      -7.683445e-07       5.164686e-06
# BBFTOP3 KY Equity      -6.997817e-09       2.189383e-07       4.558075e-08
# CRLCBUU LX Equity       2.834879e-07      -2.465525e-07       4.825812e-07
# BCUSDLF KK Equity       2.804106e-07      -1.959935e-08       1.870341e-08
# PGPGIFA ID Equity       5.832823e-06      -7.329275e-08       5.748516e-07
# PFGLAAU LX Equity       1.177909e-07      -3.012736e-07       2.763139e-07
# ALPCRDA LX Equity       5.375880e-06      -1.403663e-08      -1.117566e-07
# BUTIBLI KY Equity       1.693858e-05       6.445914e-07       1.041013e-06
#
#                    BBFTOP3 KY Equity  CRLCBUU LX Equity  BCUSDLF KK Equity  \
# AIBALMA AB Equity      -6.997817e-09       2.834879e-07       2.804106e-07
# LODFUIA LX Equity       2.189383e-07      -2.465525e-07      -1.959935e-08
# CCASORI MK Equity       4.558075e-08       4.825812e-07       1.870341e-08
# BBFTOP3 KY Equity       2.462584e-06       3.879191e-07      -1.967282e-08
# CRLCBUU LX Equity       3.879191e-07       5.600535e-06       2.600089e-08
# BCUSDLF KK Equity      -1.967282e-08       2.600089e-08       1.082739e-07
# PGPGIFA ID Equity      -3.308211e-07       7.652617e-07       2.463935e-07
# PFGLAAU LX Equity      -4.210615e-07       7.854867e-07       7.856294e-08
# ALPCRDA LX Equity      -9.380534e-07      -1.113672e-06       1.023685e-07
# BUTIBLI KY Equity      -2.354613e-06      -1.939311e-06      -8.323661e-08
#
#                    PGPGIFA ID Equity  PFGLAAU LX Equity  ALPCRDA LX Equity  \
# AIBALMA AB Equity       5.832823e-06       1.177909e-07       5.375880e-06
# LODFUIA LX Equity      -7.329275e-08      -3.012736e-07      -1.403663e-08
# CCASORI MK Equity       5.748516e-07       2.763139e-07      -1.117566e-07
# BBFTOP3 KY Equity      -3.308211e-07      -4.210615e-07      -9.380534e-07
# CRLCBUU LX Equity       7.652617e-07       7.854867e-07      -1.113672e-06
# BCUSDLF KK Equity       2.463935e-07       7.856294e-08       1.023685e-07
# PGPGIFA ID Equity       9.436773e-06      -1.086948e-07      -5.335569e-07
# PFGLAAU LX Equity      -1.086948e-07       3.071178e-05       4.369781e-06
# ALPCRDA LX Equity      -5.335569e-07       4.369781e-06       1.490646e-05
# BUTIBLI KY Equity       6.396113e-06       1.136959e-05       1.461637e-05
#
#                    BUTIBLI KY Equity
# AIBALMA AB Equity       1.693858e-05
# LODFUIA LX Equity       6.445914e-07
# CCASORI MK Equity       1.041013e-06
# BBFTOP3 KY Equity      -2.354613e-06
# CRLCBUU LX Equity      -1.939311e-06
# BCUSDLF KK Equity      -8.323661e-08
# PGPGIFA ID Equity       6.396113e-06
# PFGLAAU LX Equity       1.136959e-05
# ALPCRDA LX Equity       1.461637e-05
# BUTIBLI KY Equity       1.261157e-04

# %%
Ret_Corr = Ret.corr()
print(Ret_Corr)
# Out:
#                    AIBALMA AB Equity  LODFUIA LX Equity  CCASORI MK Equity  \
# AIBALMA AB Equity           1.000000           0.057520           0.272233
# LODFUIA LX Equity           0.057520           1.000000          -0.356253
# CCASORI MK Equity           0.272233          -0.356253           1.000000
# BBFTOP3 KY Equity          -0.000618           0.147011           0.012781
# CRLCBUU LX Equity           0.016609          -0.109779           0.089729
# BCUSDLF KK Equity           0.118154          -0.062763           0.025011
# PGPGIFA ID Equity           0.263260          -0.025140           0.082342
# PFGLAAU LX Equity           0.002947          -0.057284           0.021940
# ALPCRDA LX Equity           0.193055          -0.003831          -0.012737
# BUTIBLI KY Equity           0.209127           0.060482           0.040790
#
#                    BBFTOP3 KY Equity  CRLCBUU LX Equity  BCUSDLF KK Equity  \
# AIBALMA AB Equity          -0.000618           0.016609           0.118154
# LODFUIA LX Equity           0.147011          -0.109779          -0.062763
# CCASORI MK Equity           0.012781           0.089729           0.025011
# BBFTOP3 KY Equity           1.000000           0.104455          -0.038099
# CRLCBUU LX Equity           0.104455           1.000000           0.033390
# BCUSDLF KK Equity          -0.038099           0.033390           1.000000
# PGPGIFA ID Equity          -0.068626           0.105265           0.243756
# PFGLAAU LX Equity          -0.048417           0.059892           0.043083
# ALPCRDA LX Equity          -0.154826          -0.121886           0.080578
# BUTIBLI KY Equity          -0.133610          -0.072971          -0.022525
#
#                    PGPGIFA ID Equity  PFGLAAU LX Equity  ALPCRDA LX Equity  \
# AIBALMA AB Equity           0.263260           0.002947           0.193055
# LODFUIA LX Equity          -0.025140          -0.057284          -0.003831
# CCASORI MK Equity           0.082342           0.021940          -0.012737
# BBFTOP3 KY Equity          -0.068626          -0.048417          -0.154826
# CRLCBUU LX Equity           0.105265           0.059892          -0.121886
# BCUSDLF KK Equity           0.243756           0.043083           0.080578
# PGPGIFA ID Equity           1.000000          -0.006385          -0.044986
# PFGLAAU LX Equity          -0.006385           1.000000           0.204230
# ALPCRDA LX Equity          -0.044986           0.204230           1.000000
# BUTIBLI KY Equity           0.185404           0.182687           0.337107
#
#                    BUTIBLI KY Equity
# AIBALMA AB Equity           0.209127
# LODFUIA LX Equity           0.060482
# CCASORI MK Equity           0.040790
# BBFTOP3 KY Equity          -0.133610
# CRLCBUU LX Equity          -0.072971
# BCUSDLF KK Equity          -0.022525
# PGPGIFA ID Equity           0.185404
# PFGLAAU LX Equity           0.182687
# ALPCRDA LX Equity           0.337107
# BUTIBLI KY Equity           1.000000

# %% [markdown]
# # Creation of portfolio

# %%
# Log of percentage change and create Covariance matrix
cov_matrix = Stocks.pct_change().apply(lambda x: np.log(1+x)).cov()
cov_matrix
# Out:
#                    AIBALMA AB Equity  LODFUIA LX Equity  CCASORI MK Equity  \
# AIBALMA AB Equity       5.201934e-05       3.937103e-07       4.462164e-06
# LODFUIA LX Equity       3.937103e-07       9.006414e-07      -7.683445e-07
# CCASORI MK Equity       4.462164e-06      -7.683445e-07       5.164686e-06
# BBFTOP3 KY Equity      -6.997817e-09       2.189383e-07       4.558075e-08
# CRLCBUU LX Equity       2.834879e-07      -2.465525e-07       4.825812e-07
# BCUSDLF KK Equity       2.804106e-07      -1.959935e-08       1.870341e-08
# PGPGIFA ID Equity       5.832823e-06      -7.329275e-08       5.748516e-07
# PFGLAAU LX Equity       1.177909e-07      -3.012736e-07       2.763139e-07
# ALPCRDA LX Equity       5.375880e-06      -1.403663e-08      -1.117566e-07
# BUTIBLI KY Equity       1.693858e-05       6.445914e-07       1.041013e-06
#
#                    BBFTOP3 KY Equity  CRLCBUU LX Equity  BCUSDLF KK Equity  \
# AIBALMA AB Equity      -6.997817e-09       2.834879e-07       2.804106e-07
# LODFUIA LX Equity       2.189383e-07      -2.465525e-07      -1.959935e-08
# CCASORI MK Equity       4.558075e-08       4.825812e-07       1.870341e-08
# BBFTOP3 KY Equity       2.462584e-06       3.879191e-07      -1.967282e-08
# CRLCBUU LX Equity       3.879191e-07       5.600535e-06       2.600089e-08
# BCUSDLF KK Equity      -1.967282e-08       2.600089e-08       1.082739e-07
# PGPGIFA ID Equity      -3.308211e-07       7.652617e-07       2.463935e-07
# PFGLAAU LX Equity      -4.210615e-07       7.854867e-07       7.856294e-08
# ALPCRDA LX Equity      -9.380534e-07      -1.113672e-06       1.023685e-07
# BUTIBLI KY Equity      -2.354613e-06      -1.939311e-06      -8.323661e-08
#
#                    PGPGIFA ID Equity  PFGLAAU LX Equity  ALPCRDA LX Equity  \
# AIBALMA AB Equity       5.832823e-06       1.177909e-07       5.375880e-06
# LODFUIA LX Equity      -7.329275e-08      -3.012736e-07      -1.403663e-08
# CCASORI MK Equity       5.748516e-07       2.763139e-07      -1.117566e-07
# BBFTOP3 KY Equity      -3.308211e-07      -4.210615e-07      -9.380534e-07
# CRLCBUU LX Equity       7.652617e-07       7.854867e-07      -1.113672e-06
# BCUSDLF KK Equity       2.463935e-07       7.856294e-08       1.023685e-07
# PGPGIFA ID Equity       9.436773e-06      -1.086948e-07      -5.335569e-07
# PFGLAAU LX Equity      -1.086948e-07       3.071178e-05       4.369781e-06
# ALPCRDA LX Equity      -5.335569e-07       4.369781e-06       1.490646e-05
# BUTIBLI KY Equity       6.396113e-06       1.136959e-05       1.461637e-05
#
#                    BUTIBLI KY Equity
# AIBALMA AB Equity       1.693858e-05
# LODFUIA LX Equity       6.445914e-07
# CCASORI MK Equity       1.041013e-06
# BBFTOP3 KY Equity      -2.354613e-06
# CRLCBUU LX Equity      -1.939311e-06
# BCUSDLF KK Equity      -8.323661e-08
# PGPGIFA ID Equity       6.396113e-06
# PFGLAAU LX Equity       1.136959e-05
# ALPCRDA LX Equity       1.461637e-05
# BUTIBLI KY Equity       1.261157e-04

# %%
corr_matrix = Stocks.pct_change().apply(lambda x: np.log(1+x)).corr()
corr_matrix
# Out:
#                    AIBALMA AB Equity  LODFUIA LX Equity  CCASORI MK Equity  \
# AIBALMA AB Equity           1.000000           0.057520           0.272233
# LODFUIA LX Equity           0.057520           1.000000          -0.356253
# CCASORI MK Equity           0.272233          -0.356253           1.000000
# BBFTOP3 KY Equity          -0.000618           0.147011           0.012781
# CRLCBUU LX Equity           0.016609          -0.109779           0.089729
# BCUSDLF KK Equity           0.118154          -0.062763           0.025011
# PGPGIFA ID Equity           0.263260          -0.025140           0.082342
# PFGLAAU LX Equity           0.002947          -0.057284           0.021940
# ALPCRDA LX Equity           0.193055          -0.003831          -0.012737
# BUTIBLI KY Equity           0.209127           0.060482           0.040790
#
#                    BBFTOP3 KY Equity  CRLCBUU LX Equity  BCUSDLF KK Equity  \
# AIBALMA AB Equity          -0.000618           0.016609           0.118154
# LODFUIA LX Equity           0.147011          -0.109779          -0.062763
# CCASORI MK Equity           0.012781           0.089729           0.025011
# BBFTOP3 KY Equity           1.000000           0.104455          -0.038099
# CRLCBUU LX Equity           0.104455           1.000000           0.033390
# BCUSDLF KK Equity          -0.038099           0.033390           1.000000
# PGPGIFA ID Equity          -0.068626           0.105265           0.243756
# PFGLAAU LX Equity          -0.048417           0.059892           0.043083
# ALPCRDA LX Equity          -0.154826          -0.121886           0.080578
# BUTIBLI KY Equity          -0.133610          -0.072971          -0.022525
#
#                    PGPGIFA ID Equity  PFGLAAU LX Equity  ALPCRDA LX Equity  \
# AIBALMA AB Equity           0.263260           0.002947           0.193055
# LODFUIA LX Equity          -0.025140          -0.057284          -0.003831
# CCASORI MK Equity           0.082342           0.021940          -0.012737
# BBFTOP3 KY Equity          -0.068626          -0.048417          -0.154826
# CRLCBUU LX Equity           0.105265           0.059892          -0.121886
# BCUSDLF KK Equity           0.243756           0.043083           0.080578
# PGPGIFA ID Equity           1.000000          -0.006385          -0.044986
# PFGLAAU LX Equity          -0.006385           1.000000           0.204230
# ALPCRDA LX Equity          -0.044986           0.204230           1.000000
# BUTIBLI KY Equity           0.185404           0.182687           0.337107
#
#                    BUTIBLI KY Equity
# AIBALMA AB Equity           0.209127
# LODFUIA LX Equity           0.060482
# CCASORI MK Equity           0.040790
# BBFTOP3 KY Equity          -0.133610
# CRLCBUU LX Equity          -0.072971
# BCUSDLF KK Equity          -0.022525
# PGPGIFA ID Equity           0.185404
# PFGLAAU LX Equity           0.182687
# ALPCRDA LX Equity           0.337107
# BUTIBLI KY Equity           1.000000

# %%
plt.subplots(figsize=(14,10))
sp.heatmap(corr_matrix, linewidths=0.6)
# Out:
# <AxesSubplot:>

# %%
return_risk_ratio = (Ann_Ret/Ann_Risk)
assets = pd.concat([Ann_Ret, Ann_Risk, return_risk_ratio], axis=1) # Creating a table for visualising returns and volatility of assets
assets.columns = ['Returns', 'Volatility','Returns to Risk']
assets
# Out:
#                     Returns  Volatility  Returns to Risk
# AIBALMA AB Equity  0.164994    0.052010         3.172365
# LODFUIA LX Equity  0.020183    0.006843         2.949239
# CCASORI MK Equity  0.077905    0.016388         4.753824
# BBFTOP3 KY Equity  0.059322    0.011316         5.242223
# CRLCBUU LX Equity  0.047072    0.017065         2.758347
# BCUSDLF KK Equity  0.007076    0.002373         2.982097
# PGPGIFA ID Equity  0.061577    0.022152         2.779728
# PFGLAAU LX Equity  0.090445    0.039963         2.263234
# ALPCRDA LX Equity  0.091994    0.027841         3.304219
# BUTIBLI KY Equity  0.135671    0.080982         1.675332

# %%
# Yearly returns for individual companies
ind_er = Stocks.resample('Y').last().pct_change().mean()
ind_er
# Out:
# AIBALMA AB Equity    0.076369
# LODFUIA LX Equity    0.013253
# CCASORI MK Equity    0.038140
# BBFTOP3 KY Equity    0.040926
# CRLCBUU LX Equity    0.022385
# BCUSDLF KK Equity    0.002768
# PGPGIFA ID Equity    0.021034
# PFGLAAU LX Equity    0.038815
# ALPCRDA LX Equity    0.019602
# BUTIBLI KY Equity    0.049820
# dtype: float64

# %%
# EQ weighted portfolio's risk
w = [1/10]*10 
port_var = cov_matrix.mul(w, axis=0).mul(w, axis=1).sum().sum()
Ann_port_std = (port_var*52)**(0.5)
print(Ann_port_std)
# Out:
# 0.014074036387331764

# %%
# Portfolio returns
w = [1/10]*10
port_er = (w*Ann_Ret).sum()
port_er
# Out:
# 0.07562378791735364

# %%
import matplotlib.pyplot as plt
x = Ann_Risk # RISK
y = Ann_Ret # Return
plt.scatter(x, y)
plt.show()

# %%
#creating portfolios random n =10000
p_ret = [] # Define an empty array for portfolio returns
p_vol = [] # Define an empty array for portfolio volatility
p_weights = [] # Define an empty array for asset weights
num_assets = len(Stocks.columns)
num_portfolios = 100000
#explain

# %%
for portfolio in range(num_portfolios):
    weights = np.random.random(num_assets)
    weights = weights/np.sum(weights)
    p_weights.append(weights)
    returns = np.dot(weights, Ann_Ret) # Returns are the product of individual expected returns of asset and its
    # weights
    p_ret.append(returns)
    var = cov_matrix.mul(weights, axis=0).mul(weights, axis=1).sum().sum() # Portfolio Variance
    sd = np.sqrt(var) #Daily standard deviation
    ann_sd = sd*np.sqrt(52) #Annual standard deviation = volatility
    p_vol.append(ann_sd)

# %%
data = {'Returns':p_ret, 'Volatility':p_vol}
for counter, symbol in enumerate(Stocks.columns.tolist()):
 #print(counter, symbol)
 data[symbol+' weight'] = [w[counter] for w in p_weights]
portfolios = pd.DataFrame(data)
portfolios.head() # Dataframe of the 10000 portfolios created
#explain
# Out:
#     Returns  Volatility  AIBALMA AB Equity weight  LODFUIA LX Equity weight  \
# 0  0.084308    0.016936                  0.193640                  0.173387
# 1  0.076362    0.015642                  0.123805                  0.010567
# 2  0.078998    0.015881                  0.098940                  0.024768
# 3  0.070245    0.010539                  0.038693                  0.174643
# 4  0.062388    0.007991                  0.011228                  0.169927
#
#    CCASORI MK Equity weight  BBFTOP3 KY Equity weight  \
# 0                  0.196863                  0.028811
# 1                  0.041196                  0.029345
# 2                  0.105341                  0.158713
# 3                  0.221154                  0.108981
# 4                  0.177540                  0.189006
#
#    CRLCBUU LX Equity weight  BCUSDLF KK Equity weight  \
# 0                  0.102347                  0.022284
# 1                  0.159253                  0.171637
# 2                  0.142323                  0.080757
# 3                  0.085600                  0.031030
# 4                  0.123127                  0.046792
#
#    PGPGIFA ID Equity weight  PFGLAAU LX Equity weight  \
# 0                  0.119866                  0.056019
# 1                  0.169610                  0.071245
# 2                  0.149290                  0.019720
# 3                  0.046615                  0.046487
# 4                  0.053113                  0.081163
#
#    ALPCRDA LX Equity weight  BUTIBLI KY Equity weight
# 0                  0.002228                  0.104556
# 1                  0.117402                  0.105940
# 2                  0.081577                  0.138571
# 3                  0.186936                  0.059860
# 4                  0.109203                  0.038903

# %%
# Plot the returns and risks of the 10000 portfolios
x=Ann_Risk
y=Ann_Ret
portfolios.plot.scatter(x='Volatility', y='Returns', marker='o', s=10, alpha=0.3, grid=True, figsize=[11,8])
# Out:
# <AxesSubplot:xlabel='Volatility', ylabel='Returns'>

# %%
min_vol_port = portfolios.iloc[portfolios['Volatility'].idxmin()]
# idxmin() gives us the minimum value in the column specified.
#gives portfolio with min value of risk
min_vol_port
# Out:
# Returns                     0.038704
# Volatility                  0.004440
# AIBALMA AB Equity weight    0.000764
# LODFUIA LX Equity weight    0.268025
# CCASORI MK Equity weight    0.069270
# BBFTOP3 KY Equity weight    0.208624
# CRLCBUU LX Equity weight    0.166491
# BCUSDLF KK Equity weight    0.219817
# PGPGIFA ID Equity weight    0.011828
# PFGLAAU LX Equity weight    0.001691
# ALPCRDA LX Equity weight    0.048869
# BUTIBLI KY Equity weight    0.004621
# Name: 99475, dtype: float64

# %%
# plotting the minimum volatility portfolio with max return associated with the min amount of risk
plt.subplots(figsize=[11,8])
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=200)

# %%
# Finding the optimal portfolio
rf = 0.05 # risk factor, risk aversion factor
optimal_risky_port = portfolios.iloc[((portfolios['Returns']-rf)/portfolios['Volatility']).idxmax()]
optimal_risky_port
#max (Return - risk factor / risk)
# Out:
# Returns                     0.087837
# Volatility                  0.013236
# AIBALMA AB Equity weight    0.154296
# LODFUIA LX Equity weight    0.017676
# CCASORI MK Equity weight    0.305339
# BBFTOP3 KY Equity weight    0.190052
# CRLCBUU LX Equity weight    0.063134
# BCUSDLF KK Equity weight    0.014584
# PGPGIFA ID Equity weight    0.001954
# PFGLAAU LX Equity weight    0.052276
# ALPCRDA LX Equity weight    0.187511
# BUTIBLI KY Equity weight    0.013178
# Name: 9322, dtype: float64

# %%
# Plotting optimal portfolio
plt.subplots(figsize=(11, 8))
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)
plt.scatter(optimal_risky_port[1], optimal_risky_port[0], color='g', marker='*', s=500)
